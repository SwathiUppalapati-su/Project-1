# %%
# import libraries
import pandas as pd
import numpy as np
import pymysql

# %%
#csv to dataframe
df_buses_1=pd.read_csv(r"C:\Users\phani\Downloads\capstone\redbus\df_buses_1.csv")
df_buses_2=pd.read_csv(r"C:\Users\phani\Downloads\capstone\redbus\df_buses_2.csv")
df_buses_3=pd.read_csv(r"C:\Users\phani\Downloads\capstone\redbus\df_buses_3.csv")
df_buses_4=pd.read_csv(r"C:\Users\phani\Downloads\capstone\redbus\df_buses_4.csv")
df_buses_5=pd.read_csv(r"C:\Users\phani\Downloads\capstone\redbus\df_buses_5.csv")
df_buses_6=pd.read_csv(r"C:\Users\phani\Downloads\capstone\redbus\df_buses_6.csv")
df_buses_8=pd.read_csv(r"C:\Users\phani\Downloads\capstone\redbus\df_buses_8.csv")
df_buses_9=pd.read_csv(r"C:\Users\phani\Downloads\capstone\redbus\df_buses_9.csv")
df_buses_10=pd.read_csv(r"C:\Users\phani\Downloads\capstone\redbus\df_buses_10.csv")
df_buses_11=pd.read_csv(r"C:\Users\phani\Downloads\capstone\redbus\df_buses_11.csv")

Final_df=pd.concat([df_buses_1,df_buses_2,df_buses_3,df_buses_4,df_buses_5,df_buses_6,
                    df_buses_8,df_buses_9,df_buses_10,df_buses_11],ignore_index=True)
Final_df
# Out:
#                    Bus_name                                   Bus_type  \
# 0      KSRTC (Kerala) - 588  Super Express Non AC Seater Air Bus (2+2)
# 1     KSRTC (Kerala) - 2367                    Low Floor AC Seater 2+2
# 2     KSRTC (Kerala) - 2388                    Low Floor AC Seater 2+2
# 3     KSRTC (Kerala) - 1106     SWIFT-HYBRID NON AC SEATER CUM SLEEPER
# 4      KSRTC (Kerala) - 486  Super Express Non AC Seater Air Bus (2+2)
# ...                     ...                                        ...
# 7662             HRTC - 927                 Ordinary 3+2 Non AC Seater
# 7663   New Himalaya Travels               Volvo A/C Semi Sleeper (2+2)
# 7664           Bedi Travels          Volvo 9600 A/C Semi Sleeper (2+2)
# 7665     Ram Dalal Holidays          Volvo 9600 A/C Semi Sleeper (2+2)
# 7666       Northern Travels               Volvo A/C Semi Sleeper (2+2)
#
#      Start_time End_time Total_duration    Price     Seats_Available Ratings  \
# ...

# %% [markdown]
# # DATA CLEANING

# %%
path=r"C:\Users\phani\Downloads\capstone\redbus\Final_df.csv"
Final_df.to_csv(path,index=False)

# %%
Final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7667 entries, 0 to 7666
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         7622 non-null   object
#  1   Bus_type         7619 non-null   object
#  2   Start_time       7622 non-null   object
#  3   End_time         7622 non-null   object
#  4   Total_duration   7622 non-null   object
#  5   Price            7622 non-null   float64
#  6   Seats_Available  7622 non-null   object
#  7   Ratings          7667 non-null   float64
#  8   Route_link       7667 non-null   object
#  9   Route_name       7667 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 599.1+ KB

# %%
#convert prices to numeric
Final_df["Price"]=Final_df["Price"].str.replace("INR","")
Final_df["Price"]=Final_df["Price"].astype(float)
Final_df["Price"].fillna(0)
# Out:
# 0       555.0
# 1       742.0
# 2       723.0
# 3       565.0
# 4       586.0
#         ...
# 7662    303.0
# 7663    500.0
# 7664    621.0
# 7665    580.0
# 7666    519.0
# Name: Price, Length: 7667, dtype: float64

# %%
# Ensure all values in the "Ratings" column are strings
Final_df["Ratings"] = Final_df["Ratings"].astype(str)

# Now apply the string manipulations
Final_df["Ratings"] = Final_df["Ratings"].str.replace("New", " ")
Final_df["Ratings"] = Final_df["Ratings"].str.strip()
Final_df["Ratings"] = Final_df["Ratings"].str.split().str[0]

# Convert the cleaned-up "Ratings" column to numeric, filling non-numeric values with 0
Final_df["Ratings"] = pd.to_numeric(Final_df["Ratings"], errors='coerce')
Final_df["Ratings"].fillna(0, inplace=True)
# Out:
# C:\Users\phani\AppData\Local\Temp\ipykernel_29504\2671312623.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Final_df["Ratings"].fillna(0, inplace=True)

# %%
Final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7667 entries, 0 to 7666
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         7622 non-null   object
#  1   Bus_type         7619 non-null   object
#  2   Start_time       7622 non-null   object
#  3   End_time         7622 non-null   object
#  4   Total_duration   7622 non-null   object
#  5   Price            7622 non-null   float64
#  6   Seats_Available  7622 non-null   object
#  7   Ratings          7667 non-null   float64
#  8   Route_link       7667 non-null   object
#  9   Route_name       7667 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 599.1+ KB

# %%
Final_df = Final_df[Final_df["Price"] <= 7000]

# %%
# replacing the nan value
Final_df = Final_df.replace({np.nan: None})

# %%
# change dataframe to csv
path=r"C:\Users\phani\Downloads\capstone\redbus\Final_df1.csv"
Final_df.to_csv(path,index=False)
